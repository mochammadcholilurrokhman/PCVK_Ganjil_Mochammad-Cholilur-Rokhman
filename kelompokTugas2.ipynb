# %% [markdown]
# <a href="https://colab.research.google.com/github/mochammadcholilurrokhman/PCVK_Ganjil_Mochammad-Cholilur-Rokhman/blob/main/kelompokTugas2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/KTP.jpg')
img_rgb = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img_rgb)
image_ktp = img_rgb.copy()

# %%
tinggi = image_ktp.shape[0]
lebar = image_ktp.shape[1]

# %%
# cv.rectangle(img, pt1=(192,328), pt2=(480,345), color=(255,0,0), thickness=-1)
# cv.rectangle(img, pt1=(192,352), pt2=(230,368), color=(255,255,255), thickness=-1)

# Misalkan img adalah gambar yang sudah dimuat sebelumnya
image_ktp2 = image_ktp.copy()
font = cv.FONT_HERSHEY_SIMPLEX

# Menggambar teks pada image_ktp2
cv.putText(image_ktp2, text='XXXXXXXXXXXXXXXXXXXXXXXXXXX', org=(int(0.2375*lebar), int(0.69672*tinggi)), fontFace=font, fontScale=tinggi/813, color=(255,0,0), thickness=int(lebar/200), lineType=cv.LINE_AA)
cv.putText(image_ktp2, text='XXXX', org=(int(0.2375*lebar), int(0.75*tinggi)), fontFace=font, fontScale=tinggi/813, color=(255,255,0), thickness=int(lebar/200), lineType=cv.LINE_AA)

# Mengonversi gambar dari BGR ke RGB

# Menampilkan gambar dengan matplotlib
plt.imshow(image_ktp2)
plt.axis('off')  # Menyembunyikan sumbu
plt.show()
