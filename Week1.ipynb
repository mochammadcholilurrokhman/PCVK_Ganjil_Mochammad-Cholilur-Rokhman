# %% [markdown]
# <a href="https://colab.research.google.com/github/mochammadcholilurrokhman/PCVK_Ganjil_Mochammad-Cholilur-Rokhman/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
import requests
from io import BytesIO

urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://www.newsdone.com/wp-content/uploads/2020/08/cat-british-shorthair-cat-s-eyes-british.jpg"]

headers = {'User-Agent': 'Mozilla/5.0'}

for url in urls:
  # Use requests to fetch image data with custom headers
  response = requests.get(url, headers=headers)
  image = io.imread(BytesIO(response.content))

  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=910x304>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  304  x  455
# <PIL.Image.Image image mode=RGB size=455x304>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
 image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=910x304>

# %%
JAWABAN
1. Karena Google Colab memungkinkan penggunanya untuk menulis dan mengeksekusi Python di browser (Chrome, Firefox dan Safari) tanpa memerlukan konfigurasi,
   dapat mengakses GPU secara gratis, serta dapat berbagi kode program (kolaborasi tim) dengan mudah.
2. Numpy adalah perpustakaan manipulasi array, digunakan untuk aljabar linier, transformasi Fourier, dan kemampuan bilangan acak
   -Pandas adalah perpustakaan untuk manipulasi data dan analisis data. -CV2 adalah perpustakaan untuk tugas-tugas visi komputer.
   -Skimage adalah perpustakaan yang mendukung aplikasi pengolah gambar dengan python.
   -Matplotlib adalah perpustakaan yang menghasilkan gambar dan menyediakan perangkat antarmuka pengguna grafis.
3. Kode diatas untuk merubah ukuran gambar fx untuk lebar sedangkan fy untuk tinggi
4. Untuk mengatur warna RGB menjadi putih
5. pixel dan resolusi saling berhubungan dalam menentukan kualitas gambar. Semakin banyak pixel dan semakin tinggi resolusinya, semakin baik gambar yang dihasilkan.

# %%
Tugas

2. Buat garis vertikal dan garis menyilang diagonal pada image keluaran

# %%
# Mengonversi gambar ke format RGB
image_2 = cv.cvtColor(image.copy(), cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image.copy(), cv.COLOR_BGR2RGB)
image_4 = cv.cvtColor(image.copy(), cv.COLOR_BGR2RGB)
image_5 = cv.cvtColor(image.copy(), cv.COLOR_BGR2RGB)
# Membuat garis vertikal di tengah gambar (putih)
for y in range(tinggi):
    image_3[y, int(lebar / 2)] = [255, 255, 255]

thickness = 2

# Membuat garis diagonal
cv.line(image_5, (0, 0), (lebar - 1, tinggi - 1), (255, 255, 255), thickness)
cv.line(image_5, (0, tinggi - 1), (lebar - 1, 0), (255, 255, 255), thickness)


# Menggabungkan gambar awal dengan gambar yang telah diberi garis vertikal
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
print ('\n')
final_frame = cv.hconcat((image_4, image_5))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=910x304>
# <PIL.Image.Image image mode=RGB size=910x304>

# %%
3. Buat garis horisontal berwarna putih dibagian tengah gambar dengan panjang
tertentu

# %%
image_2 = cv.cvtColor(image.copy(), cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image.copy(), cv.COLOR_BGR2RGB)

# Panjang garis yang diinginkan (misalnya, setengah dari lebar gambar)
panjang_garis = lebar // 2

# Menghitung posisi vertikal tengah gambar
y_pos = tinggi // 2

# Membuat titik awal dan titik akhir untuk garis horizontal
x1 = (lebar - panjang_garis) // 2
x2 = x1 + panjang_garis

# Membuat gambar dengan garis horizontal
gambar_horizontal = cv.line(image_3, (x1, y_pos), (x2, y_pos), [255,255,255], 2)

# Menampilkan gambar hasilnya
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=910x304>

# %%
4. Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam
gambar
# Out:
#   File "<ipython-input-81-43b56fa48a3a>", line 1
#     4. Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam
#        ^
# SyntaxError: invalid syntax

# %%
image_2 = cv.cvtColor(image.copy(), cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image.copy(), cv.COLOR_BGR2RGB)

# Ukuran dan posisi kotak yang diinginkan
x1 = 100  # Koordinat x kiri atas
y1 = 100  # Koordinat y kiri atas
x2 = 200  # Koordinat x kanan bawah
y2 = 200  # Koordinat y kanan bawah

# Define the rectangle color
color = (255, 255, 255)  # White color

# Draw the rectangle using nested loops
for y in range(y1, y2):
    for x in range(x1, x2):
        image_3[y, x] = color

# Menampilkan gambar hasilnya
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=910x304>
